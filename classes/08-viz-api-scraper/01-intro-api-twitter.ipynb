# %% [markdown]
# [![AnalyticsDojo](https://s3.amazonaws.com/analyticsdojo/logo/final-logo.png)](http://rpi.analyticsdojo.com)
# <center><h1>Introduction to API's with Python</h1></center>
# <center><h3><a href = 'http://rpi.analyticsdojo.com'>rpi.analyticsdojo.com</a></h3></center>

# %% [markdown]
# This is adopted from [Mining the Social Web, 2nd Edition](http://bit.ly/16kGNyb)
# Copyright (c) 2013, Matthew A. Russell
# All rights reserved.
#
# This work is licensed under the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt).

# %% [markdown]
# ### Before you Begin #1
# If you are working locally, this exercise requires the twitter package, which unlike previous packages needs pip as an installer.
# `!pip install twitter`
#
# If you get an error that pip is not available, you might have to install it.  See
# https://conda.io/docs/user-guide/tasks/manage-pkgs.html.
#
# The package should be available online at lab.analyticsdojo.com (nothing to Install)

# %%
#see if it worked by importing the twitter package & some other things we will use.  
from  twitter import *
import datetime, traceback 
import json
import time
import sys

# %% [markdown]
# ### Before you Begin #2
# In the twitter directory you will see a configuration file called configsample.yaml.  We are going to store our Twitter keys in there.  These Twitter keys are used instead of passwords to programatically allow access to your
#
# 1. Copy `configsample.yaml` to `config.yaml`.
# 2. Create an ID on Twitter or login if you already have a Twitter account.
# 3. Create a twitter app.  Go to [apps.twitter.com](https://apps.twitter.com) and click on create a new app.  You will then be able to access the needed fields for the config.yaml file.
# 4. Update config.yaml to include appropriate Twitter keys.
# 5. Update screen_names.csv to include the ids of interest.
# 6. Download your config file to somewhere outside this directory just in case you update the repository it might be lost.

# %% [markdown]
# ## Step1.  Loading Authorization Data
# - Here we are going to store the authorization data in a .YAML file rather than directly in the notebook.
# - We have also added `config.yaml` to the `.gitignore` file so we won't accidentally commit our sensitive data to the repository.
# - You should generally keep sensitive data out of all git repositories (public or private) but definitely Public.
# - If you ever accidentally commit data to a public repository you must consider it compromised.
# - A .yaml file is a common way to store configuration data, but it is not really secure.

# %%
#This will import some required libraries.
import sys 
import ruamel.yaml #A .yaml file 
#This is your configuration file. 
twitter_yaml='./twitter/config.yaml'
with open(twitter_yaml, 'r') as yaml_t:
    cf_t=ruamel.yaml.round_trip_load(yaml_t, preserve_quotes=True)


#You can check your config was loaded by printing, but you should not commit this.
#print(cf_t)

# %% [markdown]
# ## Create Some Relevant Functions
# - We first will create a Twitter object we can used to authorize data.
# - Then we will get profiles.
# - Finally we will

# %%
def create_twitter_auth(cf_t):
        """Function to create a twitter object
           Args: cf_t is configuration dictionary. 
           Returns: Twitter object.
            """
        # When using twitter stream you must authorize.
        # these tokens are necessary for user authentication
        # create twitter API object

        auth = OAuth(cf_t['access_token'], cf_t['access_token_secret'], cf_t['consumer_key'], cf_t['consumer_secret'])

        try:
            # create twitter API object
            twitter = Twitter(auth = auth)
        except TwitterHTTPError:
            traceback.print_exc()
            time.sleep(cf_t['sleep_interval'])
        return twitter

# %%
def get_profiles(twitter, names, cf_t):
    """Function write profiles to a file with the form *data-user-profiles.json*
       Args: names is a list of names
             cf_t is a list of twitter config
       Returns: Nothing
        """
    # file name for daily tracking
    dt = datetime.datetime.now()
    fn = cf_t['data']+'/profiles/'+dt.strftime('%Y-%m-%d-user-profiles.json')
    with open(fn, 'w') as f:
        for name in names:
            print("Searching twitter for User profile: ", name)
            try:
                # create a subquery, looking up information about these users
                # twitter API docs: https://dev.twitter.com/docs/api/1/get/users/lookup
                profiles = twitter.users.lookup(screen_name = name)
                sub_start_time = time.time()
                for profile in profiles:
                    print("User found. Total tweets:", profile['statuses_count'])
                    # now save user info
                    f.write(json.dumps(profile))
                    f.write("\n")
                sub_elapsed_time = time.time() - sub_start_time;
                if sub_elapsed_time < cf_t['sleep_interval']:
                    time.sleep(cf_t['sleep_interval'] + 1 - sub_elapsed_time)
            except TwitterHTTPError:
                traceback.print_exc()
                time.sleep(cf_t['sleep_interval'])
                continue
    f.close()
    return fn

# %% [markdown]
# ## Load Twitter Handle From CSV
# - This is a .csv that has individuals we want to collect data on.
# - Go ahead and follow [AnalyticsDojo](https://twitter.com/AnalyticsDojo).

# %%
import pandas as pd
df=pd.DataFrame.from_csv(cf_t['config']+"/"+cf_t['file'])
df
# Out:
#            screen_name
# index
# 1           tensorflow
# 2      DeepLearningHub

# %% [markdown]
# ## Create Twitter Object

# %%
#Create Twitter Object
twitter= create_twitter_auth(cf_t)

# %%
#This will get general profile data
profiles_fn=get_profiles(twitter, df['screen_name'], cf_t)
# Out:
# Searching twitter for User profile:  tensorflow
# User found. Total tweets: 144
# Searching twitter for User profile:  DeepLearningHub
# User found. Total tweets: 2404

# %% [markdown]
# The outcoming of running the above API is to generate a twitter object.

# %% [markdown]
# ## Step 2. Getting Help

# %%
# We can get some help on how to use the twitter api with the following. 
help(twitter)
# Out:
# Help on Twitter in module twitter.api object:
#
# class Twitter(TwitterCall)
#  |  The minimalist yet fully featured Twitter API class.
#  |
#  |  Get RESTful data by accessing members of this class. The result
#  |  is decoded python objects (lists and dicts).
#  |
#  |  The Twitter API is documented at:
#  |
#  |    http://dev.twitter.com/doc
#  |
#  |
#  |  Examples::
#  |
#  |      from twitter import *
#  |
#  |      t = Twitter(
#  |          auth=OAuth(token, token_key, con_secret, con_secret_key))
#  |
#  |      # Get your "home" timeline
#  |      t.statuses.home_timeline()
#  |
#  |      # Get a particular friend's timeline
#  |      t.statuses.user_timeline(screen_name="billybob")
#  |
#  |      # to pass in GET/POST parameters, such as `count`
#  |      t.statuses.home_timeline(count=5)
#  |
#  |      # to pass in the GET/POST parameter `id` you need to use `_id`
#  |      t.statuses.oembed(_id=1234567890)
#  |
#  |      # Update your status
#  |      t.statuses.update(
#  |          status="Using @sixohsix's sweet Python Twitter Tools.")
#  |
#  |      # Send a direct message
#  |      t.direct_messages.new(
#  |          user="billybob",
#  |          text="I think yer swell!")
#  |
#  |      # Get the members of tamtar's list "Things That Are Rad"
#  |      t.lists.members(owner_screen_name="tamtar", slug="things-that-are-rad")
#  |
#  |      # An *optional* `_timeout` parameter can also be used for API
#  |      # calls which take much more time than normal or twitter stops
#  |      # responding for some reason:
#  |      t.users.lookup(
#  |          screen_name=','.join(A_LIST_OF_100_SCREEN_NAMES),             _timeout=1)
#  |
#  |      # Overriding Method: GET/POST
#  |      # you should not need to use this method as this library properly
#  |      # detects whether GET or POST should be used, Nevertheless
#  |      # to force a particular method, use `_method`
#  |      t.statuses.oembed(_id=1234567890, _method='GET')
#  |
#  |      # Send images along with your tweets:
#  |      # - first just read images from the web or from files the regular way:
#  |      with open("example.png", "rb") as imagefile:
#  |          imagedata = imagefile.read()
#  |      # - then upload medias one by one on Twitter's dedicated server
#  |      #   and collect each one's id:
#  |      t_up = Twitter(domain='upload.twitter.com',
#  |          auth=OAuth(token, token_key, con_secret, con_secret_key))
#  |      id_img1 = t_up.media.upload(media=imagedata)["media_id_string"]
#  |      id_img2 = t_up.media.upload(media=imagedata)["media_id_string"]
#  |
#  |      # - finally send your tweet with the list of media ids:
#  |      t.statuses.update(status="PTT ★", media_ids=",".join([id_img1, id_img2]))
#  |
#  |      # Or send a tweet with an image (or set a logo/banner similarily)
#  |      # using the old deprecated method that will probably disappear some day
#  |      params = {"media[]": imagedata, "status": "PTT ★"}
#  |      # Or for an image encoded as base64:
#  |      params = {"media[]": base64_image, "status": "PTT ★", "_base64": True}
#  |      t.statuses.update_with_media(**params)
#  |
#  |
#  |
#  |  Searching Twitter::
#  |
#  |      # Search for the latest tweets about #pycon
#  |      t.search.tweets(q="#pycon")
#  |
#  |
#  |  Using the data returned
#  |  -----------------------
#  |
#  |  Twitter API calls return decoded JSON. This is converted into
#  |  a bunch of Python lists, dicts, ints, and strings. For example::
#  |
#  |      x = twitter.statuses.home_timeline()
#  |
#  |      # The first 'tweet' in the timeline
#  |      x[0]
#  |
#  |      # The screen name of the user who wrote the first 'tweet'
#  |      x[0]['user']['screen_name']
#  |
#  |
#  |  Getting raw XML data
#  |  --------------------
#  |
#  |  If you prefer to get your Twitter data in XML format, pass
#  |  format="xml" to the Twitter object when you instantiate it::
#  |
#  |      twitter = Twitter(format="xml")
#  |
#  |  The output will not be parsed in any way. It will be a raw string
#  |  of XML.
#  |
#  |  Method resolution order:
#  |      Twitter
#  |      TwitterCall
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, format='json', domain='api.twitter.com', secure=True, auth=None, api_version=<class 'twitter.api._DEFAULT'>, retry=False)
#  |      Create a new twitter API connector.
#  |
#  |      Pass an `auth` parameter to use the credentials of a specific
#  |      user. Generally you'll want to pass an `OAuth`
#  |      instance::
#  |
#  |          twitter = Twitter(auth=OAuth(
#  |                  token, token_secret, consumer_key, consumer_secret))
#  |
#  |
#  |      `domain` lets you change the domain you are connecting. By
#  |      default it's `api.twitter.com`.
#  |
#  |      If `secure` is False you will connect with HTTP instead of
#  |      HTTPS.
#  |
#  |      `api_version` is used to set the base uri. By default it's
#  |      '1.1'.
#  |
#  |      If `retry` is True, API rate limits will automatically be
#  |      handled by waiting until the next reset, as indicated by
#  |      the X-Rate-Limit-Reset HTTP header. If retry is an integer,
#  |      it defines the number of retries attempted.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from TwitterCall:
#  |
#  |  __call__(self, **kwargs)
#  |      Call self as a function.
#  |
#  |  __getattr__(self, k)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from TwitterCall:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from TwitterCall:
#  |
#  |  TWITTER_UNAVAILABLE_WAIT = 30

# %% [markdown]
# Go ahead and take a look at the [twitter docs](https://dev.twitter.com/rest/public).

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter.trends.place(_id=US_WOE_ID)

print (world_trends)
print (us_trends)
# Out:
# [{'as_of': '2017-10-02T23:15:33Z', 'locations': [{'name': 'Worldwide', 'woeid': 1}], 'trends': [{'url': 'http://twitter.com/search?q=%22Tom+Petty%22', 'name': 'Tom Petty', 'query': '%22Tom+Petty%22', 'tweet_volume': 595670, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23GFvip', 'name': '#GFvip', 'query': '%23GFvip', 'tweet_volume': 190550, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23ahoraqueARV', 'name': '#ahoraqueARV', 'query': '%23ahoraqueARV', 'tweet_volume': 22822, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23%D9%88%D9%84%D9%8A_%D8%A7%D9%84%D8%B9%D9%87%D8%AF_%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA_%D9%85%D8%AC%D8%A7%D9%86%D8%A7', 'name': '#ولي_العهد_المباريات_مجانا', 'query': '%23%D9%88%D9%84%D9%8A_%D8%A7%D9%84%D8%B9%D9%87%D8%AF_%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA_%D9%85%D8%AC%D8%A7%D9%86%D8%A7', 'tweet_volume': 48718, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23QQCCMH3', 'name': '#QQCCMH3', 'query': '%23QQCCMH3', 'tweet_volume': 11052, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23%D8%A7%D9%85_%D9%83%D9%84%D8%AB%D9%88%D9%85_%D8%AA%D8%B9%D9%88%D8%AF_%D9%84%D9%84%D9%82%D9%86%D8%A7%D9%87_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87', 'name': '#ام_كلثوم_تعود_للقناه_السعوديه', 'query': '%23%D8%A7%D9%85_%D9%83%D9%84%D8%AB%D9%88%D9%85_%D8%AA%D8%B9%D9%88%D8%AF_%D9%84%D9%84%D9%82%D9%86%D8%A7%D9%87_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87', 'tweet_volume': 26685, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22J%C3%BAlia+Peixoto%22', 'name': 'Júlia Peixoto', 'query': '%22J%C3%BAlia+Peixoto%22', 'tweet_volume': 16749, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Evangelina+Elizondo%22', 'name': 'Evangelina Elizondo', 'query': '%22Evangelina+Elizondo%22', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Melih+G%C3%B6k%C3%A7ek%22', 'name': 'Melih Gökçek', 'query': '%22Melih+G%C3%B6k%C3%A7ek%22', 'tweet_volume': 35012, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Bill+O%27Reilly%22', 'name': "Bill O'Reilly", 'query': '%22Bill+O%27Reilly%22', 'tweet_volume': 11510, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22%D8%AD%D9%85%D8%AF+%D8%A7%D9%84%D8%B5%D9%86%D9%8A%D8%B9%22', 'name': 'حمد الصنيع', 'query': '%22%D8%AD%D9%85%D8%AF+%D8%A7%D9%84%D8%B5%D9%86%D9%8A%D8%B9%22', 'tweet_volume': 25288, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Derek+Carr%22', 'name': 'Derek Carr', 'query': '%22Derek+Carr%22', 'tweet_volume': 15773, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Jorge+Glas%22', 'name': 'Jorge Glas', 'query': '%22Jorge+Glas%22', 'tweet_volume': 22815, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22LUCIFER+IS+BACK%22', 'name': 'LUCIFER IS BACK', 'query': '%22LUCIFER+IS+BACK%22', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=LaMelo', 'name': 'LaMelo', 'query': 'LaMelo', 'tweet_volume': 10243, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23MdTPapaLuna', 'name': '#MdTPapaLuna', 'query': '%23MdTPapaLuna', 'tweet_volume': 10315, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23%D8%A7%D8%B9%D9%81%D8%A7%D8%A1_%D8%A7%D9%84%D8%AD%D8%A7%D9%8A%D9%84%D9%8A_%D9%84%D8%B4%D8%A8%D9%87%D9%87_%D8%AA%D8%B2%D9%88%D9%8A%D8%B1', 'name': '#اعفاء_الحايلي_لشبهه_تزوير', 'query': '%23%D8%A7%D8%B9%D9%81%D8%A7%D8%A1_%D8%A7%D9%84%D8%AD%D8%A7%D9%8A%D9%84%D9%8A_%D9%84%D8%B4%D8%A8%D9%87%D9%87_%D8%AA%D8%B2%D9%88%D9%8A%D8%B1', 'tweet_volume': 24305, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23MeCambio90', 'name': '#MeCambio90', 'query': '%23MeCambio90', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23%D9%86%D8%B7%D8%A7%D9%84%D8%A8_%D8%A7%D9%84%D8%BA%D8%A7%D8%A1_%D9%88%D9%84%D8%A7%D9%8A%D9%87_%D8% ...
# [{'as_of': '2017-10-02T23:15:33Z', 'locations': [{'name': 'United States', 'woeid': 23424977}], 'trends': [{'url': 'http://twitter.com/search?q=%22Tom+Petty%22', 'name': 'Tom Petty', 'query': '%22Tom+Petty%22', 'tweet_volume': 595670, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23VegasStrong', 'name': '#VegasStrong', 'query': '%23VegasStrong', 'tweet_volume': 21363, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Bill+O%27Reilly%22', 'name': "Bill O'Reilly", 'query': '%22Bill+O%27Reilly%22', 'tweet_volume': 11510, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=LaMelo', 'name': 'LaMelo', 'query': 'LaMelo', 'tweet_volume': 10243, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Derek+Carr%22', 'name': 'Derek Carr', 'query': '%22Derek+Carr%22', 'tweet_volume': 15773, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23NeverLoanPeople', 'name': '#NeverLoanPeople', 'query': '%23NeverLoanPeople', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Traveling+Wilburys%22', 'name': 'Traveling Wilburys', 'query': '%22Traveling+Wilburys%22', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23tytlive', 'name': '#tytlive', 'query': '%23tytlive', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23rethinkingPHL', 'name': '#rethinkingPHL', 'query': '%23rethinkingPHL', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Amber+Alert%22', 'name': 'Amber Alert', 'query': '%22Amber+Alert%22', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23WASvsKC', 'name': '#WASvsKC', 'query': '%23WASvsKC', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Shannon+Sharpe%22', 'name': 'Shannon Sharpe', 'query': '%22Shannon+Sharpe%22', 'tweet_volume': 32566, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Andrew+Nembhard%22', 'name': 'Andrew Nembhard', 'query': '%22Andrew+Nembhard%22', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Sarah+Sanders%22', 'name': 'Sarah Sanders', 'query': '%22Sarah+Sanders%22', 'tweet_volume': 32999, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Clark+County%22', 'name': 'Clark County', 'query': '%22Clark+County%22', 'tweet_volume': 16194, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Michael+Beasley%22', 'name': 'Michael Beasley', 'query': '%22Michael+Beasley%22', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=Arrowhead', 'name': 'Arrowhead', 'query': 'Arrowhead', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Dear+Hate%22', 'name': 'Dear Hate', 'query': '%22Dear+Hate%22', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Text+ACT+to+64433%22', 'name': 'Text ACT to 64433', 'query': '%22Text+ACT+to+64433%22', 'tweet_volume': 30072, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Google+and+Facebook%22', 'name': 'Google and Facebook', 'query': '%22Google+and+Facebook%22', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Alex+Jones%22', 'name': 'Alex Jones', 'query': '%22Alex+Jones%22', 'tweet_volume': 23992, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%22Clinging+to+Life%22', 'name': 'Clinging to Life', 'query': '%22Clinging+to+Life%22', 'tweet_volume': 20229, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23GunContolNow', 'name': '#GunContolNow', 'query': '%23GunContolNow', 'tweet_volume': None, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23CamsBald', 'name': '#CamsBald', 'query': '%23CamsBald', 'tweet_volume': 19262, 'promoted_content': None}, {'url': 'http://twitter.com/search?q=%23NoAb ...

# %% [markdown]
# ## Step 3. Displaying API responses as pretty-printed JSON

# %%
import json

print (json.dumps(world_trends, indent=1))
print (json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "as_of": "2017-10-02T23:15:33Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ],
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%22Tom+Petty%22",
#     "name": "Tom Petty",
#     "query": "%22Tom+Petty%22",
#     "tweet_volume": 595670,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GFvip",
#     "name": "#GFvip",
#     "query": "%23GFvip",
#     "tweet_volume": 190550,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ahoraqueARV",
#     "name": "#ahoraqueARV",
#     "query": "%23ahoraqueARV",
#     "tweet_volume": 22822,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%88%D9%84%D9%8A_%D8%A7%D9%84%D8%B9%D9%87%D8%AF_%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA_%D9%85%D8%AC%D8%A7%D9%86%D8%A7",
#     "name": "#\u0648\u0644\u064a_\u0627\u0644\u0639\u0647\u062f_\u0627\u0644\u0645\u0628\u0627\u0631\u064a\u0627\u062a_\u0645\u062c\u0627\u0646\u0627",
#     "query": "%23%D9%88%D9%84%D9%8A_%D8%A7%D9%84%D8%B9%D9%87%D8%AF_%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA_%D9%85%D8%AC%D8%A7%D9%86%D8%A7",
#     "tweet_volume": 48718,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23QQCCMH3",
#     "name": "#QQCCMH3",
#     "query": "%23QQCCMH3",
#     "tweet_volume": 11052,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%85_%D9%83%D9%84%D8%AB%D9%88%D9%85_%D8%AA%D8%B9%D9%88%D8%AF_%D9%84%D9%84%D9%82%D9%86%D8%A7%D9%87_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87",
#     "name": "#\u0627\u0645_\u0643\u0644\u062b\u0648\u0645_\u062a\u0639\u0648\u062f_\u0644\u0644\u0642\u0646\u0627\u0647_\u0627\u0644\u0633\u0639\u0648\u062f\u064a\u0647",
#     "query": "%23%D8%A7%D9%85_%D9%83%D9%84%D8%AB%D9%88%D9%85_%D8%AA%D8%B9%D9%88%D8%AF_%D9%84%D9%84%D9%82%D9%86%D8%A7%D9%87_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87",
#     "tweet_volume": 26685,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22J%C3%BAlia+Peixoto%22",
#     "name": "J\u00falia Peixoto",
#     "query": "%22J%C3%BAlia+Peixoto%22",
#     "tweet_volume": 16749,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Evangelina+Elizondo%22",
#     "name": "Evangelina Elizondo",
#     "query": "%22Evangelina+Elizondo%22",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Melih+G%C3%B6k%C3%A7ek%22",
#     "name": "Melih G\u00f6k\u00e7ek",
#     "query": "%22Melih+G%C3%B6k%C3%A7ek%22",
#     "tweet_volume": 35012,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Bill+O%27Reilly%22",
#     "name": "Bill O'Reilly",
#     "query": "%22Bill+O%27Reilly%22",
#     "tweet_volume": 11510,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22%D8%AD%D9%85%D8%AF+%D8%A7%D9%84%D8%B5%D9%86%D9%8A%D8%B9%22",
#     "name": "\u062d\u0645\u062f \u0627\u0644\u0635\u0646\u064a\u0639",
#     "query": "%22%D8%AD%D9%85%D8%AF+%D8%A7%D9%84%D8%B5%D9%86%D9%8A%D8%B9%22",
#     "tweet_volume": 25288,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Derek+Carr%22",
#     "name": "Derek Carr",
#     "query": "%22Derek+Carr%22",
#     "tweet_volume": 15773,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Jorge+Glas%22",
#     "name": "Jorge Glas",
#     "query": "%22Jorge+Glas%22",
#     "tweet_volume": 22815,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22LUCIFER+IS+BACK%22",
#     "name": "LUCIFER IS BACK",
#     "query": "%22LUCIFER+IS+BACK%22",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=LaMelo",
#     "name": "LaMelo",
#     "query": "LaMelo",
#     "tweet_volume": 10243,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MdTPapaLuna",
#     "name": "#MdTPapaLuna",
#     "query": "%23MdTPapaLuna",
#     "tweet_volume": 10315,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D8%B9%D9%81%D8%A7%D8%A1_%D8%A7%D9%84%D8%AD%D8%A7%D9%8A%D9%84%D9%8A_%D9%84%D8%B4%D8%A8%D9%87%D9%87_%D8%AA%D8%B2%D9%88%D9%8A%D8%B1",
#     "name": "#\u0627\u0639\u0641\u0627\u0621_\u0627\u0644\u062d\u0627\u064a\u0644\u064a_\u0644\u0634\u0628\u0647\u0647_\u062a\u0632\u0648\u064a\u0631",
#     "query": "%23%D8%A7%D8%B9%D9%81%D8%A7%D8%A1_%D8%A7%D9%84%D8%AD%D8%A7%D9%8A%D9%84%D9%8A_%D9%84%D8%B4%D8%A8%D9%87%D9%87_%D8%AA%D8%B2%D9%88%D9%8A%D8%B1",
#     "tweet_volume": 24305,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MeCambio90",
#     "name": "#MeCambio90",
#     "query": "%23MeCambio90",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%86%D8%B7%D8%A7%D9%84%D8%A8_%D8%A7%D9%84%D8%BA%D8%A7%D8%A1_%D9%88%D9%84%D8%A7%D9%8A%D9%87_%D8%A7%D9%84%D8%B3%D9%81%D8%B1",
#     "name": "#\u0646\u0637\u0627\u0644\u0628_\u0627\u0644\u063a\u0627\u0621_\u0648\u0644\u0627\u064a\u0647_\u0627\u0644\u0633\u0641\u0631",
#     "query": "%23%D9%86%D8%B7%D8%A7%D9%84%D8%A8_%D8%A7%D9%84%D8%BA%D8%A7%D8%A1_%D9%88%D9%84%D8%A7%D9%8A%D9%87_%D8%A7%D9%84%D8%B3%D9%81%D8%B1",
#     "tweet_volume": 46097,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FirstDates",
#     "name": "#FirstDates",
#     "query": "%23FirstDates",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23VegasStrong",
#     "name": "#VegasStrong",
#     "query": "%23VegasStrong",
#     "tweet_volume": 21363,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%88%D8%B4_%D8%AD%D8%A7%D8%B7_%D8%AE%D9%84%D9%81%D9%8A%D9%87_%D8%AC%D9%88%D8%A7%D9%84",
#     "name": "#\u0648\u0634_\u062d\u0627\u0637_\u062e\u0644\u0641\u064a\u0647_\u062c\u0648\u0627\u0644",
#     "query": "%23%D9%88%D8%B4_%D8%AD%D8%A7%D8%B7_%D8%AE%D9%84%D9%81%D9%8A%D9%87_%D8%AC%D9%88%D8%A7%D9%84",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MiCasaAnaTorroja",
#     "name": "#MiCasaAnaTorroja",
#     "query": "%23MiCasaAnaTorroja",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Liar",
#     "name": "#Liar",
#     "query": "%23Liar",
#     "tweet_volume": 10589,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%83%D9%8A%D9%81_%D8%A7%D8%A8%D8%B7%D9%84_%D8%AA%D8%AF%D8%AE%D9%8A%D9%86",
#     "name": "#\u0643\u064a\u0641_\u0627\u0628\u0637\u0644_\u062a\u062f\u062e\u064a\u0646",
#     "query": "%23%D9%83%D9%8A%D9%81_%D8%A7%D8%A8%D8%B7%D9%84_%D8%AA%D8%AF%D8%AE%D9%8A%D9%86",
#     "tweet_volume": 12138,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23guncontrol",
#     "name": "#guncontrol",
#     "query": "%23guncontrol",
#     "tweet_volume": 121254,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TodosNaMafiaSdv",
#     "name": "#TodosNaMafiaSdv",
#     "query": "%23TodosNaMafiaSdv",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GetWellSoonNormani",
#     "name": "#GetWellSoonNormani",
#     "query": "%23GetWellSoonNormani",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FaltaUnaLeyQ",
#     "name": "#FaltaUnaLeyQ",
#     "query": "%23FaltaUnaLeyQ",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%B3%D9%87%D9%85_%D9%84%D8%A7%D8%B2%D9%88%D8%B1%D8%AF%D9%8A_%D9%8A%D8%A7_%D9%88%D9%84%D9%8A_%D8%A7%D9%84%D8%B9%D9%87%D8%AF",
#     "name": "#\u0633\u0647\u0645_\u0644\u0627\u0632\u0648\u0631\u062f\u064a_\u064a\u0627_\u0648\u0644\u064a_\u0627\u0644\u0639\u0647\u062f",
#     "query": "%23%D8%B3%D9%87%D9%85_%D9%84%D8%A7%D8%B2%D9%88%D8%B1%D8%AF%D9%8A_%D9%8A%D8%A7_%D9%88%D9%84%D9%8A_%D8%A7%D9%84%D8%B9%D9%87%D8%AF",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CamsBald",
#     "name": "#CamsBald",
#     "query": "%23CamsBald",
#     "tweet_volume": 19262,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ADP2017",
#     "name": "#ADP2017",
#     "query": "%23ADP2017",
#     "tweet_volume": 10378,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MeDaPorRezarCuando",
#     "name": "#MeDaPorRezarCuando",
#     "query": "%23MeDaPorRezarCuando",
#     "tweet_volume": 24253,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%235x1EnMTVHITS",
#     "name": "#5x1EnMTVHITS",
#     "query": "%235x1EnMTVHITS",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ChiringuitoPiqu%C3%A9",
#     "name": "#ChiringuitoPiqu\u00e9",
#     "query": "%23ChiringuitoPiqu%C3%A9",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PelisConAntidisturbios",
#     "name": "#PelisConAntidisturbios",
#     "query": "%23PelisConAntidisturbios",
#     "tweet_volume": 20150,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HoyLunesNoOlvidesQue",
#     "name": "#HoyLunesNoOlvidesQue",
#     "query": "%23HoyLunesNoOlvidesQue",
#     "tweet_volume": 24581,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CristinaEnSanMartin",
#     "name": "#CristinaEnSanMartin",
#     "query": "%23CristinaEnSanMartin",
#     "tweet_volume": 11467,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%B9%D9%88%D8%AF%D9%87_%D8%A7%D9%84%D8%AD%D9%81%D9%84%D8%A7%D8%AA_%D8%A7%D9%84%D8%BA%D9%86%D8%A7%D9%8A%D9%8A%D9%87",
#     "name": "#\u0639\u0648\u062f\u0647_\u0627\u0644\u062d\u0641\u0644\u0627\u062a_\u0627\u0644\u063a\u0646\u0627\u064a\u064a\u0647",
#     "query": "%23%D8%B9%D9%88%D8%AF%D9%87_%D8%A7%D9%84%D8%AD%D9%81%D9%84%D8%A7%D8%AA_%D8%A7%D9%84%D8%BA%D9%86%D8%A7%D9%8A%D9%8A%D9%87",
#     "tweet_volume": 11606,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D8%B3%D8%A7%D9%84_%D8%B3%D9%88%D8%A7%D9%84_%D9%85%D8%AD%D9%8A%D8%B1%D9%83",
#     "name": "#\u0627\u0633\u0627\u0644_\u0633\u0648\u0627\u0644_\u0645\u062d\u064a\u0631\u0643",
#     "query": "%23%D8%A7%D8%B3%D8%A7%D9%84_%D8%B3%D9%88%D8%A7%D9%84_%D9%85%D8%AD%D9%8A%D8%B1%D9%83",
#     "tweet_volume": 52732,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SiALaJEP",
#     "name": "#SiALaJEP",
#     "query": "%23SiALaJEP",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23VagaGeneral3O",
#     "name": "#VagaGeneral3O",
#     "query": "%23VagaGeneral3O",
#     "tweet_volume": 26669,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%83%D9%84_%D9%85%D8%A7_%D8%AA%D8%B7%D8%B1%D9%8A_%D8%B9%D9%84%D9%8A_%D8%A8%D8%A7%D9%84%D9%8A_%D8%A7%D9%82%D9%88%D9%84",
#     "name": "#\u0643\u0644_\u0645\u0627_\u062a\u0637\u0631\u064a_\u0639\u0644\u064a_\u0628\u0627\u0644\u064a_\u0627\u0642\u0648\u0644",
#     "query": "%23%D9%83%D9%84_%D9%85%D8%A7_%D8%AA%D8%B7%D8%B1%D9%8A_%D8%B9%D9%84%D9%8A_%D8%A8%D8%A7%D9%84%D9%8A_%D8%A7%D9%82%D9%88%D9%84",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23VaiQueColaNoTVZ",
#     "name": "#VaiQueColaNoTVZ",
#     "query": "%23VaiQueColaNoTVZ",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PongamonosSerios",
#     "name": "#PongamonosSerios",
#     "query": "%23PongamonosSerios",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23greyroomng",
#     "name": "#greyroomng",
#     "query": "%23greyroomng",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Furore",
#     "name": "#Furore",
#     "query": "%23Furore",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LaConsultaVa",
#     "name": "#LaConsultaVa",
#     "query": "%23LaConsultaVa",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NeverLoanPeople",
#     "name": "#NeverLoanPeople",
#     "query": "%23NeverLoanPeople",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AndaluciaCuenta1O_CSur",
#     "name": "#AndaluciaCuenta1O_CSur",
#     "query": "%23AndaluciaCuenta1O_CSur",
#     "tweet_volume": null,
#     "promoted_content": null
#    }
#   ],
#   "created_at": "2017-10-02T23:08:24Z"
#  }
# ]
# [
#  {
#   "as_of": "2017-10-02T23:15:33Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ],
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%22Tom+Petty%22",
#     "name": "Tom Petty",
#     "query": "%22Tom+Petty%22",
#     "tweet_volume": 595670,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23VegasStrong",
#     "name": "#VegasStrong",
#     "query": "%23VegasStrong",
#     "tweet_volume": 21363,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Bill+O%27Reilly%22",
#     "name": "Bill O'Reilly",
#     "query": "%22Bill+O%27Reilly%22",
#     "tweet_volume": 11510,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=LaMelo",
#     "name": "LaMelo",
#     "query": "LaMelo",
#     "tweet_volume": 10243,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Derek+Carr%22",
#     "name": "Derek Carr",
#     "query": "%22Derek+Carr%22",
#     "tweet_volume": 15773,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NeverLoanPeople",
#     "name": "#NeverLoanPeople",
#     "query": "%23NeverLoanPeople",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Traveling+Wilburys%22",
#     "name": "Traveling Wilburys",
#     "query": "%22Traveling+Wilburys%22",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23tytlive",
#     "name": "#tytlive",
#     "query": "%23tytlive",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23rethinkingPHL",
#     "name": "#rethinkingPHL",
#     "query": "%23rethinkingPHL",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Amber+Alert%22",
#     "name": "Amber Alert",
#     "query": "%22Amber+Alert%22",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WASvsKC",
#     "name": "#WASvsKC",
#     "query": "%23WASvsKC",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Shannon+Sharpe%22",
#     "name": "Shannon Sharpe",
#     "query": "%22Shannon+Sharpe%22",
#     "tweet_volume": 32566,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Andrew+Nembhard%22",
#     "name": "Andrew Nembhard",
#     "query": "%22Andrew+Nembhard%22",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Sarah+Sanders%22",
#     "name": "Sarah Sanders",
#     "query": "%22Sarah+Sanders%22",
#     "tweet_volume": 32999,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Clark+County%22",
#     "name": "Clark County",
#     "query": "%22Clark+County%22",
#     "tweet_volume": 16194,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Michael+Beasley%22",
#     "name": "Michael Beasley",
#     "query": "%22Michael+Beasley%22",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Arrowhead",
#     "name": "Arrowhead",
#     "query": "Arrowhead",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Dear+Hate%22",
#     "name": "Dear Hate",
#     "query": "%22Dear+Hate%22",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Text+ACT+to+64433%22",
#     "name": "Text ACT to 64433",
#     "query": "%22Text+ACT+to+64433%22",
#     "tweet_volume": 30072,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Google+and+Facebook%22",
#     "name": "Google and Facebook",
#     "query": "%22Google+and+Facebook%22",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Alex+Jones%22",
#     "name": "Alex Jones",
#     "query": "%22Alex+Jones%22",
#     "tweet_volume": 23992,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Clinging+to+Life%22",
#     "name": "Clinging to Life",
#     "query": "%22Clinging+to+Life%22",
#     "tweet_volume": 20229,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GunContolNow",
#     "name": "#GunContolNow",
#     "query": "%23GunContolNow",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CamsBald",
#     "name": "#CamsBald",
#     "query": "%23CamsBald",
#     "tweet_volume": 19262,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NoAbortionBan",
#     "name": "#NoAbortionBan",
#     "query": "%23NoAbortionBan",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WrongfulConvictionDay",
#     "name": "#WrongfulConvictionDay",
#     "query": "%23WrongfulConvictionDay",
#     "tweet_volume": null,
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23RaceInTheUs",
#     "name": "#RaceInTheUs",
#     "query": "%23RaceInTheUs",
#     "tweet_volume": null,
#     "promoted_content": null
#    }
#   ],
#   "created_at": "2017-10-02T23:08:24Z"
#  }
# ]

# %% [markdown]
# Take a look at the [api docs](https://dev.twitter.com/rest/reference/get/trends/place) for the /trends/place call made above.

# %% [markdown]
# ## Step 4. Collecting search results for a targeted hashtag.

# %%
# Import unquote to prevent url encoding errors in next_results
#from urllib3 import unquote

#This can be any trending topic, but let's focus on a hashtag that is relevant to the class. 
q = '#analytics' 

count = 100

# See https://dev.twitter.com/rest/reference/get/search/tweets
search_results = twitter.search.tweets(q=q, count=count)

#This selects out 
statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor
for _ in range(5):
    print ("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
        print ("next_results", next_results)
    except: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    print (kwargs)
    search_results = twitter.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print (json.dumps(statuses[0], indent=1))
# Out:
# Length of statuses 89
# {
#  "favorite_count": 0,
#  "in_reply_to_screen_name": null,
#  "source": "<a href=\"https://twitter.com/alevergara78\" rel=\"nofollow\">realtimeApp_reactjs</a>",
#  "truncated": false,
#  "place": null,
#  "retweeted_status": {
#   "in_reply_to_screen_name": null,
#   "source": "<a href=\"http://app.sendblur.com\" rel=\"nofollow\">Social Media Publisher App </a>",
#   "truncated": true,
#   "place": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_status_id": null,
#   "coordinates": null,
#   "text": "AI 100: The Artificial Intelligence Startups Redefining Industries | #Analytics #BusinessIntelligence #RT\u2026 https://t.co/c48lDwRVOg",
#   "retweeted": false,
#   "in_reply_to_status_id_str": null,
#   "lang": "en",
#   "is_quote_status": false,
#   "favorite_count": 77,
#   "created_at": "Sun Oct 01 23:03:42 +0000 2017",
#   "contributors": null,
#   "geo": null,
#   "id": 914626908066926594,
#   "favorited": false,
#   "possibly_sensitive": false,
#   "entities": {
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/c48lDwRVOg",
#      "indices": [
#       107,
#       130
#      ],
#      "expanded_url": "https://twitter.com/i/web/status/914626908066926594",
#      "display_url": "twitter.com/i/web/status/9\u2026"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       69,
#       79
#      ],
#      "text": "Analytics"
#     },
#     {
#      "indices": [
#       80,
#       101
#      ],
#      "text": "BusinessIntelligence"
#     },
#     {
#      "indices": [
#       102,
#       105
#      ],
#      "text": "RT"
#     }
#    ],
#    "symbols": []
#   },
#   "user": {
#    "favourites_count": 131453,
#    "profile_use_background_image": true,
#    "profile_sidebar_fill_color": "DDEEF6",
#    "lang": "en",
#    "contributors_enabled": false,
#    "verified": false,
#    "profile_text_color": "333333",
#    "notifications": false,
#    "profile_background_color": "C0DEED",
#    "translator_type": "none",
#    "profile_sidebar_border_color": "C0DEED",
#    "default_profile": true,
#    "is_translator": false,
#    "profile_link_color": "1DA1F2",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "description": "Helping data driven companies generating value\u2022Top10 Influencer #BigData #DataScience #IoT #MachineLearning #AI #Analytics\u2022Join my Webinars\u00a0https://t.co/RZ3qzCeU5Y",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/456884052847386624/a69hONyQ_normal.jpeg",
#    "protected": false,
#    "created_at": "Mon Apr 16 07:55:31 +0000 2012",
#    "default_profile_image": false,
#    "listed_count": 3996,
#    "time_zone": "Amsterdam",
#    "is_translation_enabled": false,
#    "id": 555031989,
#    "location": "#NL. Also connect on LinkedIn",
#    "utc_offset": 7200,
#    "geo_enabled": true,
#    "friends_count": 97716,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/555031989/1504691055",
#    "id_str": "555031989",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/0S87KbVGYw",
#        "indices": [
#         0,
#         23
#        ],
#        "expanded_url": "http://nl.linkedin.com/pub/ronald-van-loon/0/1a/541/",
#        "display_url": "nl.linkedin.com/pub/ronald-van\u2026"
#       }
#      ]
#     },
#     "description": {
#      "urls": [
#       {
#        "url": "https://t.co/RZ3qzCeU5Y",
#        "indices": [
#         140,
#         163
#        ],
#        "expanded_url": "http://bit.ly/2jYPUyI",
#        "display_url": "bit.ly/2jYPUyI"
#       }
#      ]
#     }
#    },
#    "name": "Ronald van Loon",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/456884052847386624/a69hONyQ_normal.jpeg",
#    "followers_count": 103787,
#    "follow_request_sent": false,
#    "has_extended_profile": false,
#    "url": "https://t.co/0S87KbVGYw",
#    "following": false,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "statuses_count": 34847,
#    "screen_name": "Ronald_vanLoon"
#   },
#   "retweet_count": 66,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "in_reply_to_user_id_str": null,
#   "id_str": "914626908066926594"
#  },
#  "in_reply_to_status_id": null,
#  "coordinates": null,
#  "text": "RT @Ronald_vanLoon: AI 100: The Artificial Intelligence Startups Redefining Industries | #Analytics #BusinessIntelligence #RT https://t.co/\u2026",
#  "retweeted": false,
#  "retweet_count": 66,
#  "in_reply_to_status_id_str": null,
#  "lang": "en",
#  "is_quote_status": false,
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "created_at": "Mon Oct 02 23:17:06 +0000 2017",
#  "contributors": null,
#  "geo": null,
#  "id": 914992666844237824,
#  "favorited": false,
#  "entities": {
#   "user_mentions": [
#    {
#     "id": 555031989,
#     "name": "Ronald van Loon",
#     "indices": [
#      3,
#      18
#     ],
#     "id_str": "555031989",
#     "screen_name": "Ronald_vanLoon"
#    }
#   ],
#   "urls": [],
#   "hashtags": [
#    {
#     "indices": [
#      89,
#      99
#     ],
#     "text": "Analytics"
#    },
#    {
#     "indices": [
#      100,
#      121
#     ],
#     "text": "BusinessIntelligence"
#    },
#    {
#     "indices": [
#      122,
#      125
#     ],
#     "text": "RT"
#    }
#   ],
#   "symbols": []
#  },
#  "user": {
#   "favourites_count": 1375,
#   "profile_sidebar_fill_color": "000000",
#   "lang": "en",
#   "contributors_enabled": false,
#   "verified": false,
#   "profile_text_color": "000000",
#   "notifications": false,
#   "profile_background_color": "000000",
#   "translator_type": "none",
#   "profile_sidebar_border_color": "000000",
#   "default_profile": false,
#   "is_translator": false,
#   "profile_link_color": "02243B",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "description": "Any fool can write code that a computer can understand. Good programmers write code that humans can understand. Martin Fowler.\n#BigData  #machinelearning",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/477167045772312577/3q1ssMVN_normal.jpeg",
#   "protected": false,
#   "created_at": "Wed Jan 13 15:46:14 +0000 2010",
#   "default_profile_image": false,
#   "listed_count": 3924,
#   "time_zone": "Santiago",
#   "is_translation_enabled": false,
#   "id": 104520454,
#   "location": "Santiago, Chile",
#   "utc_offset": -10800,
#   "geo_enabled": true,
#   "friends_count": 722,
#   "profile_use_background_image": false,
#   "id_str": "104520454",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/7WtxS2cHYx",
#       "indices": [
#        0,
#        23
#       ],
#       "expanded_url": "http://cl.linkedin.com/in/alevergara",
#       "display_url": "cl.linkedin.com/in/alevergara"
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "name": "alejandro vergara",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/477167045772312577/3q1ssMVN_normal.jpeg",
#   "followers_count": 10399,
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "url": "https://t.co/7WtxS2cHYx",
#   "following": false,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "statuses_count": 576429,
#   "screen_name": "alevergara78"
#  },
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "id_str": "914992666844237824"
# }

# %%
#Print several
print (json.dumps(statuses[0:5], indent=1))
# Out:
# [
#  {
#   "favorite_count": 0,
#   "in_reply_to_screen_name": null,
#   "source": "<a href=\"https://twitter.com/alevergara78\" rel=\"nofollow\">realtimeApp_reactjs</a>",
#   "truncated": false,
#   "place": null,
#   "retweeted_status": {
#    "in_reply_to_screen_name": null,
#    "source": "<a href=\"http://app.sendblur.com\" rel=\"nofollow\">Social Media Publisher App </a>",
#    "truncated": true,
#    "place": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_status_id": null,
#    "coordinates": null,
#    "text": "AI 100: The Artificial Intelligence Startups Redefining Industries | #Analytics #BusinessIntelligence #RT\u2026 https://t.co/c48lDwRVOg",
#    "retweeted": false,
#    "in_reply_to_status_id_str": null,
#    "lang": "en",
#    "is_quote_status": false,
#    "favorite_count": 77,
#    "created_at": "Sun Oct 01 23:03:42 +0000 2017",
#    "contributors": null,
#    "geo": null,
#    "id": 914626908066926594,
#    "favorited": false,
#    "possibly_sensitive": false,
#    "entities": {
#     "user_mentions": [],
#     "urls": [
#      {
#       "url": "https://t.co/c48lDwRVOg",
#       "indices": [
#        107,
#        130
#       ],
#       "expanded_url": "https://twitter.com/i/web/status/914626908066926594",
#       "display_url": "twitter.com/i/web/status/9\u2026"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        69,
#        79
#       ],
#       "text": "Analytics"
#      },
#      {
#       "indices": [
#        80,
#        101
#       ],
#       "text": "BusinessIntelligence"
#      },
#      {
#       "indices": [
#        102,
#        105
#       ],
#       "text": "RT"
#      }
#     ],
#     "symbols": []
#    },
#    "user": {
#     "favourites_count": 131453,
#     "profile_use_background_image": true,
#     "profile_sidebar_fill_color": "DDEEF6",
#     "lang": "en",
#     "contributors_enabled": false,
#     "verified": false,
#     "profile_text_color": "333333",
#     "notifications": false,
#     "profile_background_color": "C0DEED",
#     "translator_type": "none",
#     "profile_sidebar_border_color": "C0DEED",
#     "default_profile": true,
#     "is_translator": false,
#     "profile_link_color": "1DA1F2",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "description": "Helping data driven companies generating value\u2022Top10 Influencer #BigData #DataScience #IoT #MachineLearning #AI #Analytics\u2022Join my Webinars\u00a0https://t.co/RZ3qzCeU5Y",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/456884052847386624/a69hONyQ_normal.jpeg",
#     "protected": false,
#     "created_at": "Mon Apr 16 07:55:31 +0000 2012",
#     "default_profile_image": false,
#     "listed_count": 3996,
#     "time_zone": "Amsterdam",
#     "is_translation_enabled": false,
#     "id": 555031989,
#     "location": "#NL. Also connect on LinkedIn",
#     "utc_offset": 7200,
#     "geo_enabled": true,
#     "friends_count": 97716,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/555031989/1504691055",
#     "id_str": "555031989",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "https://t.co/0S87KbVGYw",
#         "indices": [
#          0,
#          23
#         ],
#         "expanded_url": "http://nl.linkedin.com/pub/ronald-van-loon/0/1a/541/",
#         "display_url": "nl.linkedin.com/pub/ronald-van\u2026"
#        }
#       ]
#      },
#      "description": {
#       "urls": [
#        {
#         "url": "https://t.co/RZ3qzCeU5Y",
#         "indices": [
#          140,
#          163
#         ],
#         "expanded_url": "http://bit.ly/2jYPUyI",
#         "display_url": "bit.ly/2jYPUyI"
#        }
#       ]
#      }
#     },
#     "name": "Ronald van Loon",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/456884052847386624/a69hONyQ_normal.jpeg",
#     "followers_count": 103787,
#     "follow_request_sent": false,
#     "has_extended_profile": false,
#     "url": "https://t.co/0S87KbVGYw",
#     "following": false,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "profile_background_tile": false,
#     "statuses_count": 34847,
#     "screen_name": "Ronald_vanLoon"
#    },
#    "retweet_count": 66,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    },
#    "in_reply_to_user_id_str": null,
#    "id_str": "914626908066926594"
#   },
#   "in_reply_to_status_id": null,
#   "coordinates": null,
#   "text": "RT @Ronald_vanLoon: AI 100: The Artificial Intelligence Startups Redefining Industries | #Analytics #BusinessIntelligence #RT https://t.co/\u2026",
#   "retweeted": false,
#   "retweet_count": 66,
#   "in_reply_to_status_id_str": null,
#   "lang": "en",
#   "is_quote_status": false,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "created_at": "Mon Oct 02 23:17:06 +0000 2017",
#   "contributors": null,
#   "geo": null,
#   "id": 914992666844237824,
#   "favorited": false,
#   "entities": {
#    "user_mentions": [
#     {
#      "id": 555031989,
#      "name": "Ronald van Loon",
#      "indices": [
#       3,
#       18
#      ],
#      "id_str": "555031989",
#      "screen_name": "Ronald_vanLoon"
#     }
#    ],
#    "urls": [],
#    "hashtags": [
#     {
#      "indices": [
#       89,
#       99
#      ],
#      "text": "Analytics"
#     },
#     {
#      "indices": [
#       100,
#       121
#      ],
#      "text": "BusinessIntelligence"
#     },
#     {
#      "indices": [
#       122,
#       125
#      ],
#      "text": "RT"
#     }
#    ],
#    "symbols": []
#   },
#   "user": {
#    "favourites_count": 1375,
#    "profile_sidebar_fill_color": "000000",
#    "lang": "en",
#    "contributors_enabled": false,
#    "verified": false,
#    "profile_text_color": "000000",
#    "notifications": false,
#    "profile_background_color": "000000",
#    "translator_type": "none",
#    "profile_sidebar_border_color": "000000",
#    "default_profile": false,
#    "is_translator": false,
#    "profile_link_color": "02243B",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "description": "Any fool can write code that a computer can understand. Good programmers write code that humans can understand. Martin Fowler.\n#BigData  #machinelearning",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/477167045772312577/3q1ssMVN_normal.jpeg",
#    "protected": false,
#    "created_at": "Wed Jan 13 15:46:14 +0000 2010",
#    "default_profile_image": false,
#    "listed_count": 3924,
#    "time_zone": "Santiago",
#    "is_translation_enabled": false,
#    "id": 104520454,
#    "location": "Santiago, Chile",
#    "utc_offset": -10800,
#    "geo_enabled": true,
#    "friends_count": 722,
#    "profile_use_background_image": false,
#    "id_str": "104520454",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/7WtxS2cHYx",
#        "indices": [
#         0,
#         23
#        ],
#        "expanded_url": "http://cl.linkedin.com/in/alevergara",
#        "display_url": "cl.linkedin.com/in/alevergara"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "name": "alejandro vergara",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/477167045772312577/3q1ssMVN_normal.jpeg",
#    "followers_count": 10399,
#    "follow_request_sent": false,
#    "has_extended_profile": false,
#    "url": "https://t.co/7WtxS2cHYx",
#    "following": false,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "statuses_count": 576429,
#    "screen_name": "alevergara78"
#   },
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "id_str": "914992666844237824"
#  },
#  {
#   "favorite_count": 0,
#   "in_reply_to_screen_name": null,
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "truncated": false,
#   "place": null,
#   "retweeted_status": {
#    "in_reply_to_screen_name": null,
#    "source": "<a href=\"http://app.sendblur.com\" rel=\"nofollow\">Social Media Publisher App </a>",
#    "truncated": true,
#    "place": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_status_id": null,
#    "coordinates": null,
#    "text": "AI 100: The Artificial Intelligence Startups Redefining Industries | #Analytics #BusinessIntelligence #RT\u2026 https://t.co/c48lDwRVOg",
#    "retweeted": false,
#    "in_reply_to_status_id_str": null,
#    "lang": "en",
#    "is_quote_status": false,
#    "favorite_count": 77,
#    "created_at": "Sun Oct 01 23:03:42 +0000 2017",
#    "contributors": null,
#    "geo": null,
#    "id": 914626908066926594,
#    "favorited": false,
#    "possibly_sensitive": false,
#    "entities": {
#     "user_mentions": [],
#     "urls": [
#      {
#       "url": "https://t.co/c48lDwRVOg",
#       "indices": [
#        107,
#        130
#       ],
#       "expanded_url": "https://twitter.com/i/web/status/914626908066926594",
#       "display_url": "twitter.com/i/web/status/9\u2026"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        69,
#        79
#       ],
#       "text": "Analytics"
#      },
#      {
#       "indices": [
#        80,
#        101
#       ],
#       "text": "BusinessIntelligence"
#      },
#      {
#       "indices": [
#        102,
#        105
#       ],
#       "text": "RT"
#      }
#     ],
#     "symbols": []
#    },
#    "user": {
#     "favourites_count": 131453,
#     "profile_use_background_image": true,
#     "profile_sidebar_fill_color": "DDEEF6",
#     "lang": "en",
#     "contributors_enabled": false,
#     "verified": false,
#     "profile_text_color": "333333",
#     "notifications": false,
#     "profile_background_color": "C0DEED",
#     "translator_type": "none",
#     "profile_sidebar_border_color": "C0DEED",
#     "default_profile": true,
#     "is_translator": false,
#     "profile_link_color": "1DA1F2",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "description": "Helping data driven companies generating value\u2022Top10 Influencer #BigData #DataScience #IoT #MachineLearning #AI #Analytics\u2022Join my Webinars\u00a0https://t.co/RZ3qzCeU5Y",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/456884052847386624/a69hONyQ_normal.jpeg",
#     "protected": false,
#     "created_at": "Mon Apr 16 07:55:31 +0000 2012",
#     "default_profile_image": false,
#     "listed_count": 3996,
#     "time_zone": "Amsterdam",
#     "is_translation_enabled": false,
#     "id": 555031989,
#     "location": "#NL. Also connect on LinkedIn",
#     "utc_offset": 7200,
#     "geo_enabled": true,
#     "friends_count": 97716,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/555031989/1504691055",
#     "id_str": "555031989",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "https://t.co/0S87KbVGYw",
#         "indices": [
#          0,
#          23
#         ],
#         "expanded_url": "http://nl.linkedin.com/pub/ronald-van-loon/0/1a/541/",
#         "display_url": "nl.linkedin.com/pub/ronald-van\u2026"
#        }
#       ]
#      },
#      "description": {
#       "urls": [
#        {
#         "url": "https://t.co/RZ3qzCeU5Y",
#         "indices": [
#          140,
#          163
#         ],
#         "expanded_url": "http://bit.ly/2jYPUyI",
#         "display_url": "bit.ly/2jYPUyI"
#        }
#       ]
#      }
#     },
#     "name": "Ronald van Loon",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/456884052847386624/a69hONyQ_normal.jpeg",
#     "followers_count": 103787,
#     "follow_request_sent": false,
#     "has_extended_profile": false,
#     "url": "https://t.co/0S87KbVGYw",
#     "following": false,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "profile_background_tile": false,
#     "statuses_count": 34847,
#     "screen_name": "Ronald_vanLoon"
#    },
#    "retweet_count": 66,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    },
#    "in_reply_to_user_id_str": null,
#    "id_str": "914626908066926594"
#   },
#   "in_reply_to_status_id": null,
#   "coordinates": null,
#   "text": "RT @Ronald_vanLoon: AI 100: The Artificial Intelligence Startups Redefining Industries | #Analytics #BusinessIntelligence #RT https://t.co/\u2026",
#   "retweeted": false,
#   "retweet_count": 66,
#   "in_reply_to_status_id_str": null,
#   "lang": "en",
#   "is_quote_status": false,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "created_at": "Mon Oct 02 23:16:29 +0000 2017",
#   "contributors": null,
#   "geo": null,
#   "id": 914992511336144897,
#   "favorited": false,
#   "entities": {
#    "user_mentions": [
#     {
#      "id": 555031989,
#      "name": "Ronald van Loon",
#      "indices": [
#       3,
#       18
#      ],
#      "id_str": "555031989",
#      "screen_name": "Ronald_vanLoon"
#     }
#    ],
#    "urls": [],
#    "hashtags": [
#     {
#      "indices": [
#       89,
#       99
#      ],
#      "text": "Analytics"
#     },
#     {
#      "indices": [
#       100,
#       121
#      ],
#      "text": "BusinessIntelligence"
#     },
#     {
#      "indices": [
#       122,
#       125
#      ],
#      "text": "RT"
#     }
#    ],
#    "symbols": []
#   },
#   "user": {
#    "favourites_count": 290,
#    "profile_use_background_image": false,
#    "profile_sidebar_fill_color": "000000",
#    "lang": "en",
#    "contributors_enabled": false,
#    "verified": false,
#    "profile_text_color": "000000",
#    "notifications": false,
#    "profile_background_color": "000000",
#    "translator_type": "none",
#    "profile_sidebar_border_color": "000000",
#    "default_profile": false,
#    "is_translator": false,
#    "profile_link_color": "1B95E0",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "description": "Data Analyst in Silicon Valley. I share my interests: Analytics | VR/AR | Android Development | Data Science | IoT | AI | Tech, Tech, Tech",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/599005796827987968/BytArspl_normal.jpg",
#    "protected": false,
#    "created_at": "Thu May 14 23:44:24 +0000 2015",
#    "default_profile_image": false,
#    "listed_count": 175,
#    "time_zone": null,
#    "is_translation_enabled": false,
#    "id": 3195790651,
#    "location": "Silicon Valley",
#    "utc_offset": null,
#    "geo_enabled": false,
#    "friends_count": 370,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/3195790651/1479365615",
#    "id_str": "3195790651",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/Dpjn0soF46",
#        "indices": [
#         0,
#         23
#        ],
#        "expanded_url": "https://www.linkedin.com/in/kimkirk",
#        "display_url": "linkedin.com/in/kimkirk"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "name": "Kimberley Kirk",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/599005796827987968/BytArspl_normal.jpg",
#    "followers_count": 243,
#    "follow_request_sent": false,
#    "has_extended_profile": false,
#    "url": "https://t.co/Dpjn0soF46",
#    "following": false,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "statuses_count": 1130,
#    "screen_name": "KimBlievable"
#   },
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "id_str": "914992511336144897"
#  },
#  {
#   "in_reply_to_screen_name": null,
#   "source": "<a href=\"http://pikesley.org\" rel=\"nofollow\">SamReadWriteBot</a>",
#   "truncated": false,
#   "place": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_status_id": null,
#   "coordinates": null,
#   "text": "#Batman: Why the boom is already over - by @steveranger | #Analytics #IT https://t.co/QHeo07UZKJ",
#   "retweeted": false,
#   "in_reply_to_status_id_str": null,
#   "lang": "en",
#   "is_quote_status": false,
#   "favorite_count": 0,
#   "created_at": "Mon Oct 02 23:16:10 +0000 2017",
#   "contributors": null,
#   "geo": null,
#   "id": 914992434110660618,
#   "favorited": false,
#   "possibly_sensitive": false,
#   "entities": {
#    "user_mentions": [
#     {
#      "id": 113609203,
#      "name": "Steve Ranger",
#      "indices": [
#       43,
#       55
#      ],
#      "id_str": "113609203",
#      "screen_name": "steveranger"
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/QHeo07UZKJ",
#      "indices": [
#       73,
#       96
#      ],
#      "expanded_url": "http://ow.ly/YgZR30fAxhW",
#      "display_url": "ow.ly/YgZR30fAxhW"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       0,
#       7
#      ],
#      "text": "Batman"
#     },
#     {
#      "indices": [
#       58,
#       68
#      ],
#      "text": "Analytics"
#     },
#     {
#      "indices": [
#       69,
#       72
#      ],
#      "text": "IT"
#     }
#    ],
#    "symbols": []
#   },
#   "user": {
#    "favourites_count": 0,
#    "profile_sidebar_fill_color": "000000",
#    "lang": "en",
#    "contributors_enabled": false,
#    "verified": false,
#    "profile_text_color": "000000",
#    "notifications": false,
#    "profile_background_color": "000000",
#    "translator_type": "none",
#    "profile_sidebar_border_color": "000000",
#    "default_profile": false,
#    "is_translator": false,
#    "profile_link_color": "000000",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "description": "First I have to build a weird car",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/860595028896382976/r4FkYjgH_normal.jpg",
#    "protected": false,
#    "created_at": "Tue Aug 18 22:04:41 +0000 2015",
#    "default_profile_image": false,
#    "listed_count": 3230,
#    "time_zone": "Pacific Time (US & Canada)",
#    "is_translation_enabled": false,
#    "id": 3430582660,
#    "location": "Gotham ",
#    "utc_offset": -25200,
#    "geo_enabled": false,
#    "friends_count": 0,
#    "profile_use_background_image": false,
#    "id_str": "3430582660",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "name": "Big Data Batman",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/860595028896382976/r4FkYjgH_normal.jpg",
#    "followers_count": 3726,
#    "follow_request_sent": false,
#    "has_extended_profile": false,
#    "url": null,
#    "following": false,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "statuses_count": 109062,
#    "screen_name": "BigDataBatman"
#   },
#   "retweet_count": 0,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "in_reply_to_user_id_str": null,
#   "id_str": "914992434110660618"
#  },
#  {
#   "in_reply_to_screen_name": null,
#   "source": "<a href=\"https://ifttt.com\" rel=\"nofollow\">IFTTT</a>",
#   "truncated": false,
#   "place": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_status_id": null,
#   "coordinates": null,
#   "text": "RT tamaradull: \"One of the least understood is the distinction between DBMS and #analytics application functions\" via\u2026 \u2026",
#   "retweeted": false,
#   "in_reply_to_status_id_str": null,
#   "lang": "en",
#   "is_quote_status": false,
#   "favorite_count": 0,
#   "created_at": "Mon Oct 02 23:15:34 +0000 2017",
#   "contributors": null,
#   "geo": null,
#   "id": 914992281739984896,
#   "favorited": false,
#   "entities": {
#    "user_mentions": [],
#    "urls": [],
#    "hashtags": [
#     {
#      "indices": [
#       80,
#       90
#      ],
#      "text": "analytics"
#     }
#    ],
#    "symbols": []
#   },
#   "user": {
#    "favourites_count": 1037,
#    "profile_sidebar_fill_color": "785A4E",
#    "lang": "en",
#    "contributors_enabled": false,
#    "verified": false,
#    "profile_text_color": "9AB87B",
#    "notifications": false,
#    "profile_background_color": "ABB8C2",
#    "translator_type": "none",
#    "profile_sidebar_border_color": "FFFFFF",
#    "default_profile": false,
#    "is_translator": false,
#    "profile_link_color": "ABB8C2",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/467780501944537088/GRwpX2vR.png",
#    "description": "Sr. Editor. - All Analytics & InformationWeek | Tech & biz journalist. Asker of questions. Performer with Time Bandits Improv",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/677882401759076352/Qb_oa9Lg_normal.jpg",
#    "protected": false,
#    "created_at": "Wed Jun 18 13:55:38 +0000 2008",
#    "default_profile_image": false,
#    "listed_count": 362,
#    "time_zone": "Eastern Time (US & Canada)",
#    "is_translation_enabled": false,
#    "id": 15158048,
#    "location": "Philadelphia SiliconValley",
#    "utc_offset": -14400,
#    "geo_enabled": true,
#    "friends_count": 2422,
#    "profile_use_background_image": false,
#    "id_str": "15158048",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/vkvgUSr2Db",
#        "indices": [
#         0,
#         23
#        ],
#        "expanded_url": "http://www.linkedin.com/in/jessicadavis",
#        "display_url": "linkedin.com/in/jessicadavis"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "name": "Jessica Davis",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/677882401759076352/Qb_oa9Lg_normal.jpg",
#    "followers_count": 4345,
#    "follow_request_sent": false,
#    "has_extended_profile": false,
#    "url": "https://t.co/vkvgUSr2Db",
#    "following": false,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/467780501944537088/GRwpX2vR.png",
#    "profile_background_tile": false,
#    "statuses_count": 27028,
#    "screen_name": "jessicadavis"
#   },
#   "retweet_count": 0,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "in_reply_to_user_id_str": null,
#   "id_str": "914992281739984896"
#  },
#  {
#   "favorite_count": 0,
#   "in_reply_to_screen_name": null,
#   "source": "<a href=\"https://twitter.com\" rel=\"nofollow\">Flowj_simpson</a>",
#   "truncated": false,
#   "place": null,
#   "retweeted_status": {
#    "in_reply_to_screen_name": null,
#    "source": "<a href=\"http://bufferapp.com\" rel=\"nofollow\">Buffer</a>",
#    "truncated": true,
#    "place": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_status_id": null,
#    "coordinates": null,
#    "text": "Here are four data #analytics #careers that aren't a data scientist:\n\n#bigdata #datascience #blockchain #success\u2026 https://t.co/qsBEVPzoZv",
#    "retweeted": false,
#    "in_reply_to_status_id_str": null,
#    "lang": "en",
#    "is_quote_status": false,
#    "favorite_count": 0,
#    "created_at": "Mon Oct 02 23:14:31 +0000 2017",
#    "contributors": null,
#    "geo": null,
#    "id": 914992019155689472,
#    "favorited": false,
#    "possibly_sensitive": false,
#    "entities": {
#     "user_mentions": [],
#     "urls": [
#      {
#       "url": "https://t.co/qsBEVPzoZv",
#       "indices": [
#        114,
#        137
#       ],
#       "expanded_url": "https://twitter.com/i/web/status/914992019155689472",
#       "display_url": "twitter.com/i/web/status/9\u2026"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        19,
#        29
#       ],
#       "text": "analytics"
#      },
#      {
#       "indices": [
#        30,
#        38
#       ],
#       "text": "careers"
#      },
#      {
#       "indices": [
#        70,
#        78
#       ],
#       "text": "bigdata"
#      },
#      {
#       "indices": [
#        79,
#        91
#       ],
#       "text": "datascience"
#      },
#      {
#       "indices": [
#        92,
#        103
#       ],
#       "text": "blockchain"
#      },
#      {
#       "indices": [
#        104,
#        112
#       ],
#       "text": "success"
#      }
#     ],
#     "symbols": []
#    },
#    "user": {
#     "favourites_count": 0,
#     "profile_use_background_image": false,
#     "profile_sidebar_fill_color": "000000",
#     "lang": "en",
#     "contributors_enabled": false,
#     "verified": false,
#     "profile_text_color": "000000",
#     "notifications": false,
#     "profile_background_color": "000000",
#     "translator_type": "none",
#     "profile_sidebar_border_color": "000000",
#     "default_profile": false,
#     "is_translator": false,
#     "profile_link_color": "1B95E0",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "description": "We are #digital, #tech, #financial, #change and #informationsecurity #recruiters. Follow for industry news, career advice and job opportunities.",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/914840118917201921/XxGFoJgY_normal.jpg",
#     "protected": false,
#     "created_at": "Mon Apr 24 08:16:14 +0000 2017",
#     "default_profile_image": false,
#     "listed_count": 19,
#     "time_zone": null,
#     "is_translation_enabled": false,
#     "id": 856421510151647232,
#     "location": "Sydney",
#     "utc_offset": null,
#     "geo_enabled": false,
#     "friends_count": 4623,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/856421510151647232/1506950200",
#     "id_str": "856421510151647232",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "https://t.co/P3neLGfecZ",
#         "indices": [
#          0,
#          23
#         ],
#         "expanded_url": "http://www.ansonmccade.com",
#         "display_url": "ansonmccade.com"
#        }
#       ]
#      },
#      "description": {
#       "urls": []
#      }
#     },
#     "name": "Anson McCade AUS",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/914840118917201921/XxGFoJgY_normal.jpg",
#     "followers_count": 2088,
#     "follow_request_sent": false,
#     "has_extended_profile": false,
#     "url": "https://t.co/P3neLGfecZ",
#     "following": false,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "profile_background_tile": false,
#     "statuses_count": 598,
#     "screen_name": "AnsonMccadeAus"
#    },
#    "retweet_count": 2,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    },
#    "in_reply_to_user_id_str": null,
#    "id_str": "914992019155689472"
#   },
#   "in_reply_to_status_id": null,
#   "coordinates": null,
#   "text": "RT @AnsonMccadeAus: Here are four data #analytics #careers that aren't a data scientist:\n\n#bigdata #datascience #blockchain #success #defst\u2026",
#   "retweeted": false,
#   "retweet_count": 2,
#   "in_reply_to_status_id_str": null,
#   "lang": "en",
#   "is_quote_status": false,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "created_at": "Mon Oct 02 23:15:20 +0000 2017",
#   "contributors": null,
#   "geo": null,
#   "id": 914992223879561217,
#   "favorited": false,
#   "entities": {
#    "user_mentions": [
#     {
#      "id": 856421510151647232,
#      "name": "Anson McCade AUS",
#      "indices": [
#       3,
#       18
#      ],
#      "id_str": "856421510151647232",
#      "screen_name": "AnsonMccadeAus"
#     }
#    ],
#    "urls": [],
#    "hashtags": [
#     {
#      "indices": [
#       39,
#       49
#      ],
#      "text": "analytics"
#     },
#     {
#      "indices": [
#       50,
#       58
#      ],
#      "text": "careers"
#     },
#     {
#      "indices": [
#       90,
#       98
#      ],
#      "text": "bigdata"
#     },
#     {
#      "indices": [
#       99,
#       111
#      ],
#      "text": "datascience"
#     },
#     {
#      "indices": [
#       112,
#       123
#      ],
#      "text": "blockchain"
#     },
#     {
#      "indices": [
#       124,
#       132
#      ],
#      "text": "success"
#     }
#    ],
#    "symbols": []
#   },
#   "user": {
#    "favourites_count": 47820,
#    "profile_use_background_image": true,
#    "profile_sidebar_fill_color": "252429",
#    "lang": "en",
#    "contributors_enabled": false,
#    "verified": false,
#    "profile_text_color": "666666",
#    "notifications": false,
#    "profile_background_color": "1A1B1F",
#    "translator_type": "none",
#    "profile_sidebar_border_color": "181A1E",
#    "default_profile": false,
#    "is_translator": false,
#    "profile_link_color": "2FC2EF",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#    "description": "Shout out to your mom \n#YMIG #FlowJSimpson #smashentertainment\n\nofficialymig@gmail.com for booking",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/893198968817041408/7Qw5FyiU_normal.jpg",
#    "protected": false,
#    "created_at": "Thu Sep 03 19:55:10 +0000 2009",
#    "default_profile_image": false,
#    "listed_count": 1048,
#    "time_zone": "Eastern Time (US & Canada)",
#    "is_translation_enabled": false,
#    "id": 71342959,
#    "location": "Kush Gardens, NJ",
#    "utc_offset": -14400,
#    "geo_enabled": true,
#    "friends_count": 5001,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/71342959/1480530731",
#    "id_str": "71342959",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/mzcc39evAO",
#        "indices": [
#         0,
#         23
#        ],
#        "expanded_url": "https://play.spotify.com/artist/1ivX4GwxLzLwZURcrGDcIW",
#        "display_url": "play.spotify.com/artist/1ivX4Gw\u2026"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "name": "Flow J. Simpson",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/893198968817041408/7Qw5FyiU_normal.jpg",
#    "followers_count": 2773,
#    "follow_request_sent": false,
#    "has_extended_profile": false,
#    "url": "https://t.co/mzcc39evAO",
#    "following": false,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#    "profile_background_tile": false,
#    "statuses_count": 58919,
#    "screen_name": "FlowJ_Simpson"
#   },
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "id_str": "914992223879561217"
#  }
# ]

# %% [markdown]
# ## Step 5. Extracting text, screen names, and hashtags from tweets

# %%
#We can access an individual tweet like so:
statuses[1]['text']
# Out:
# 'RT @Ronald_vanLoon: AI 100: The Artificial Intelligence Startups Redefining Industries | #Analytics #BusinessIntelligence #RT https://t.co/…'

# %%
statuses[1]['entities']
# Out:
# {'hashtags': [{'indices': [89, 99], 'text': 'Analytics'},
#   {'indices': [100, 121], 'text': 'BusinessIntelligence'},
#   {'indices': [122, 125], 'text': 'RT'}],
#  'symbols': [],
#  'urls': [],
#  'user_mentions': [{'id': 555031989,
#    'id_str': '555031989',
#    'indices': [3, 18],
#    'name': 'Ronald van Loon',
#    'screen_name': 'Ronald_vanLoon'}]}

# %%
#notice the nested relationships.  We have to take notice of this to further access the data.
statuses[1]['entities']['hashtags']
# Out:
# [{'indices': [89, 99], 'text': 'Analytics'},
#  {'indices': [100, 121], 'text': 'BusinessIntelligence'},
#  {'indices': [122, 125], 'text': 'RT'}]

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

urls = [ url['url'] 
             for status in statuses
                 for url in status['entities']['urls'] ]



# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print (json.dumps(status_texts[0:5], indent=1))
print (json.dumps(screen_names[0:5], indent=1)) 
print (json.dumps(hashtags[0:5], indent=1))
print (json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @Ronald_vanLoon: AI 100: The Artificial Intelligence Startups Redefining Industries | #Analytics #BusinessIntelligence #RT https://t.co/\u2026",
#  "RT @Ronald_vanLoon: AI 100: The Artificial Intelligence Startups Redefining Industries | #Analytics #BusinessIntelligence #RT https://t.co/\u2026",
#  "#Batman: Why the boom is already over - by @steveranger | #Analytics #IT https://t.co/QHeo07UZKJ",
#  "RT tamaradull: \"One of the least understood is the distinction between DBMS and #analytics application functions\" via\u2026 \u2026",
#  "RT @AnsonMccadeAus: Here are four data #analytics #careers that aren't a data scientist:\n\n#bigdata #datascience #blockchain #success #defst\u2026"
# ]
# [
#  "Ronald_vanLoon",
#  "Ronald_vanLoon",
#  "steveranger",
#  "AnsonMccadeAus",
#  "AnsonMccadeAus"
# ]
# [
#  "Analytics",
#  "BusinessIntelligence",
#  "RT",
#  "Analytics",
#  "BusinessIntelligence"
# ]
# [
#  "RT",
#  "@Ronald_vanLoon:",
#  "AI",
#  "100:",
#  "The"
# ]

# %% [markdown]
# ## Step 6. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print (c.most_common()[:10]) # top 10, "\n")
# Out:
# [('RT', 43), ('#Analytics', 42), ('#analytics', 41), ('to', 28), ('and', 21), ('the', 21), ('#BigData', 20), ('The', 18), ('in', 17), ('#MachineLearning', 15)]
# [('Ronald_vanLoon', 5), ('Forbes', 4), ('steveranger', 3), ('techpearce2', 3), ('humanwareonline', 2), ('msarsar', 2), ('mobileftp', 2), ('AnsonMccadeAus', 2), ('AmiiThinks', 2), ('jlmico', 2)]
# [('analytics', 43), ('Analytics', 43), ('BigData', 22), ('MachineLearning', 15), ('AI', 12), ('IoT', 8), ('DataManagement', 7), ('IT', 6), ('bigdata', 6), ('MDM', 6)]
